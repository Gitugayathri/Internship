# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('/content/credit.csv')

# %%
data.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
# 3       19114.12            1824.843333                3.0  ...        Good
# 4       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# ...

# %%
data.shape
# Out:
# (37542, 28)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37542 entries, 0 to 37541
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        37542 non-null  int64
#  1   Customer_ID               37542 non-null  int64
#  2   Month                     37542 non-null  int64
#  3   Name                      37542 non-null  object
#  4   Age                       37542 non-null  float64
#  5   SSN                       37542 non-null  float64
#  6   Occupation                37542 non-null  object
#  7   Annual_Income             37542 non-null  float64
#  8   Monthly_Inhand_Salary     37542 non-null  float64
#  9   Num_Bank_Accounts         37542 non-null  float64
#  10  Num_Credit_Card           37542 non-null  float64
#  11  Interest_Rate             37542 non-null  float64
#  12  Num_of_Loan               37542 non-null  float64
# ...

# %%
data.describe()
# Out:
#                  ID   Customer_ID         Month           Age           SSN  \
# count  37542.000000  37542.000000  37542.000000  37542.000000  3.754200e+04
# mean   33788.000080  25875.666400      4.499840     33.167865  4.972579e+08
# std    16256.379296  14335.941143      2.291272     10.713133  2.916320e+08
# min     5634.000000   1006.000000      1.000000     14.000000  6.304420e+05
# 25%    19711.250000  13845.000000      2.250000     24.000000  2.419387e+08
# 50%    33788.500000  25453.000000      4.000000     33.000000  4.935174e+08
# 75%    47865.750000  38427.000000      6.000000     41.000000  7.516565e+08
# max    61943.000000  50992.000000      8.000000     56.000000  9.999573e+08
#
#        Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count   37542.000000           37542.000000       37542.000000
# mean    51195.914327            4251.642673           5.343296
# std     38748.781627            3217.943176           2.616842
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
num_col = data.select_dtypes(include=['number']).columns.tolist()
cat_col = data.select_dtypes(exclude=['number']).columns.tolist()

# %%
num_col
# Out:
# ['ID',
#  'Customer_ID',
#  'Month',
#  'Age',
#  'SSN',
#  'Annual_Income',
#  'Monthly_Inhand_Salary',
#  'Num_Bank_Accounts',
#  'Num_Credit_Card',
#  'Interest_Rate',
#  'Num_of_Loan',
#  'Delay_from_due_date',
#  'Num_of_Delayed_Payment',
#  'Changed_Credit_Limit',
#  'Num_Credit_Inquiries',
#  'Outstanding_Debt',
#  'Credit_Utilization_Ratio',
#  'Credit_History_Age',
#  'Total_EMI_per_month',
#  'Amount_invested_monthly',
#  'Monthly_Balance']

# %%
cat_col
# Out:
# ['Name',
#  'Occupation',
#  'Type_of_Loan',
#  'Credit_Mix',
#  'Payment_of_Min_Amount',
#  'Payment_Behaviour',
#  'Credit_Score']

# %%
data.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                1
# dtype: int64

# %%
# Checking for duplicates in all columns
duplicates = data[data.duplicated()]

# %%
duplicates
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
data.head(3)
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                3.0  ...        Good
# 1       19114.12            1824.843333                3.0  ...        Good
# 2       19114.12            1824.843333                3.0  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# 0            809.98                 26.822620              265.0
# 1            809.98                 31.944960              266.0
# 2            809.98                 28.609352              267.0
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# ...

# %%
cat_col
# Out:
# ['Name',
#  'Occupation',
#  'Type_of_Loan',
#  'Credit_Mix',
#  'Payment_of_Min_Amount',
#  'Payment_Behaviour',
#  'Credit_Score']

# %%
data['Type_of_Loan'].nunique()
# Out:
# 2697

# %%
data['Credit_Mix'].unique()
# Out:
# array(['Good', 'Standard', 'Bad'], dtype=object)

# %%
data['Payment_Behaviour'].unique()
# Out:
# array(['High_spent_Small_value_payments',
#        'Low_spent_Large_value_payments',
#        'Low_spent_Medium_value_payments',
#        'Low_spent_Small_value_payments',
#        'High_spent_Medium_value_payments',
#        'High_spent_Large_value_payments'], dtype=object)

# %%
data['Payment_Behaviour'].nunique()
# Out:
# 6

# %%
data['Credit_Score'].unique()
# Out:
# array(['Good', 'Standard', 'Poor', nan], dtype=object)

# %%
# Dropping id,customer id, Name, SSN, Credit mix
data=data.drop('Credit_Mix', axis=1)

# %%
data=data.drop('ID', axis=1)

# %%
data=data.drop('Customer_ID', axis=1)

# %%
data=data.drop('Name', axis=1)

# %%
data=data.drop('SSN', axis=1)

# %%
data['Credit_Score'].value_counts()
# Out:
# Standard    19812
# Poor        11097
# Good         6632
# Name: Credit_Score, dtype: int64

# %%
data['Credit_Score'].value_counts(normalize=True)
# Out:
# Standard    0.527743
# Poor        0.295597
# Good        0.176660
# Name: Credit_Score, dtype: float64

# %% [markdown]
# 53% has standard credit score, 17% with Good and 23% poor

# %%
data["Credit_Score"].value_counts().plot.pie()
# Out:
# <Axes: ylabel='Credit_Score'>

# %%
sns.scatterplot(x='Credit_Score', y='Annual_Income', data=data)
plt.title('Credit_Score vs Credit_Mix')
plt.xlabel('Credit_Score')
plt.ylabel('Credit_Mix')
plt.show()

# %%
freqgraph=data.select_dtypes(include='float64')
freqgraph.hist(figsize=(20,15))
plt.show()

# %%
sns.distplot(data['Monthly_Inhand_Salary'])
# Out:
# <Axes: xlabel='Monthly_Inhand_Salary', ylabel='Density'>

# %%
sns.countplot(x='Credit_Score',data=data,palette="mako")
# Out:
# <Axes: xlabel='Credit_Score', ylabel='count'>

# %%
data.columns
# Out:
# Index(['Month', 'Age', 'Occupation', 'Annual_Income', 'Monthly_Inhand_Salary',
#        'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan',
#        'Type_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment',
#        'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(data.corr().transpose(),annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >

# %%
sns.set_theme(style="darkgrid")
plt.figure(figsize=(20,6))
ax = sns.barplot(x="Occupation", y="Credit_Score", data=data)

# %%
num_col = data.select_dtypes(include=['number']).columns.tolist()
cat_col = data.select_dtypes(exclude=['number']).columns.tolist()

# %% [markdown]
# **OUTLIER DETECTION**

# %%
for i in num_col:
 plt.figure()
 plt.boxplot(data[i])
 plt.title(i)

# %%
data.describe()
# Out:
#               Month           Age  Annual_Income  Monthly_Inhand_Salary  \
# count  37542.000000  37542.000000   37542.000000           37542.000000
# mean       4.499840     33.167865   51195.914327            4251.642673
# std        2.291272     10.713133   38748.781627            3217.943176
# min        1.000000     14.000000    7006.520000             332.128333
# 25%        2.250000     24.000000   19519.570000            1649.957500
# 50%        4.000000     33.000000   37823.270000            3142.247500
# 75%        6.000000     41.000000   72330.980000            6020.726667
# max        8.000000     56.000000  179987.280000           15136.696667
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate   Num_of_Loan  \
# count       37542.000000     37542.000000   37542.000000  37542.000000
# mean            5.343296         5.549065      14.443397      3.551116
# std             2.616842         2.058099       8.742606      2.439581
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
data['Type_of_Loan'].unique()
# Out:
# array(['Auto Loan, Credit-Builder Loan, Personal Loan, and Home Equity Loan',
#        'Credit-Builder Loan', 'Auto Loan, Auto Loan, and Not Specified',
#        ...,
#        'Home Equity Loan, Personal Loan, Mortgage Loan, Debt Consolidation Loan, Debt Consolidation Loan, Debt Consolidation Loan, and Payday Loan',
#        'Credit-Builder Loan, Payday Loan, Payday Loan, Not Specified, and Debt Consolidation Loan',
#        'Credit-Builder Loan, Personal Loan, Payday Loan, Payday Loan, Debt Consolidation Loan, Not Specified, Student Loan, Mortgage Loan, and Auto Loan'],
#       dtype=object)

# %%
data['Type_of_Loan']= le.fit_transform(data['Type_of_Loan'])

# %%
data['Payment_Behaviour']= le.fit_transform(data['Payment_Behaviour'])

# %%
data['Credit_Score']= le.fit_transform(data['Credit_Score'])

# %%
data['Occupation']= le.fit_transform(data['Occupation'])

# %%
data['Payment_of_Min_Amount']= le.fit_transform(data['Payment_of_Min_Amount'])

# %%
data.head(3)
# Out:
#    Month   Age  Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0      1  23.0          12       19114.12            1824.843333
# 1      2  23.0          12       19114.12            1824.843333
# 2      3  23.0          12       19114.12            1824.843333
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                3.0              4.0            3.0          4.0
# 1                3.0              4.0            3.0          4.0
# 2                3.0              4.0            3.0          4.0
#
#    Type_of_Loan  ...  Num_Credit_Inquiries  Outstanding_Debt  \
# 0            57  ...                   4.0            809.98
# 1            57  ...                   4.0            809.98
# 2            57  ...                   4.0            809.98
#
#    Credit_Utilization_Ratio  Credit_History_Age  Payment_of_Min_Amount  \
# 0                 26.822620               265.0                      1
# ...

# %%
#Scaling
from sklearn import preprocessing

# %%
minmax = preprocessing.MinMaxScaler(feature_range = (0,1))

# %%
x = minmax.fit_transform(data)

# %%
x = pd.DataFrame(x)

# %%
x.describe()
# Out:
#                  0             1             2             3             4   \
# count  37542.000000  37542.000000  37542.000000  37542.000000  37542.000000
# mean       0.499977      0.456378      0.500944      0.255458      0.264750
# std        0.327325      0.255075      0.306841      0.224006      0.217361
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.178571      0.238095      0.214286      0.072338      0.089015
# 50%        0.428571      0.452381      0.500000      0.178151      0.189814
# 75%        0.714286      0.642857      0.785714      0.377640      0.384246
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                  5             6             7             8             9   \
# count  37542.000000  37542.000000  37542.000000  37542.000000  37542.000000
# mean       0.534330      0.504460      0.407376      0.394568      0.511923
# ...

# %%
#Histogram
plt.figure(figsize=(10, 6))
sns.histplot(data['Credit_Score'], bins=30, kde=True)
plt.title('Credit_Score Distribution')
plt.xlabel('Credit_Score')
plt.ylabel('Frequency')
plt.show()

# %%
data.columns
# Out:
# Index(['Month', 'Age', 'Occupation', 'Annual_Income', 'Monthly_Inhand_Salary',
#        'Num_Bank_Accounts', 'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan',
#        'Type_of_Loan', 'Delay_from_due_date', 'Num_of_Delayed_Payment',
#        'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
#Scatterplot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Annual_Income', y='Credit_Score', data=data)
plt.xlabel('Annual_Income')
plt.ylabel('Credit_Score')
plt.show()

# %%
Y = data['Credit_Score']
X = data.drop(['Credit_Score'],axis=1)

# %%
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=42)
X_ros, y_ros = ros.fit_resample(X, Y)

# %% [markdown]
#  class imbalance is addressed using the RandomOverSampler class from the imbalanced-learn library.

# %%
Y = data['Credit_Score']
X = data.drop(['Credit_Score'],axis=1)

# %%
data["Credit_Score"].value_counts().plot.pie()
# Out:
# <Axes: ylabel='Credit_Score'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size = .25,random_state=42)

# %%
 #Checking NaN values in x_train
print(x_train.isna().sum())
# Out:
# Month                       0
# Age                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# dtype: int64

# %%
# Checking NaN values in x_test
print(x_test.isna().sum())
# Out:
# Month                       0
# Age                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# dtype: int64

# %%
# Filling NaN values with mode
x_train = x_train.fillna(x_train.mean())

# %% [markdown]
# **LogisticRegression**- 54%

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
model = lr.fit(x_train,y_train)

# %%
y_predictions=model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score

# %%
#checking confusion matrix,TrueNegative will be displayed first
confusion_matrix(y_test,y_predictions)
# Out:
# array([[ 133,   24, 1555],
#        [  39,  877, 1826],
#        [ 144,  717, 4071]])

# %%
y_predictions
# Out:
# array([1, 2, 2, ..., 2, 2, 2])

# %%
print('Accuracy = ',accuracy_score(y_test,y_predictions))
print('Precision = ',precision_score(y_test,y_predictions,average='micro'))
print('Recall = ',recall_score(y_test,y_predictions,average='micro'))
print('F1 Score = ',f1_score(y_test,y_predictions,average='micro'))
# Out:
# Accuracy =  0.5413381632218197
# Precision =  0.5413381632218197
# Recall =  0.5413381632218197
# F1 Score =  0.5413381632218197

# %% [markdown]
# **kNN**

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
metric_k = []
neighbors=np.arange(3,15)

# %%
for k in neighbors:
  classifier = KNeighborsClassifier(n_neighbors= k, metric = 'euclidean')
  classifier.fit(x_train,y_train)
  y_pred = classifier.predict(x_test)
  acc = accuracy_score(y_test,y_pred)
  metric_k.append(acc)

# %%
metric_k
# Out:
# [0.779458768378436,
#  0.7863839761346687,
#  0.782228851480929,
#  0.7791391434050714,
#  0.7676326443639463,
#  0.7528233539313872,
#  0.7343916471340294,
#  0.7146814404432132,
#  0.6925207756232687,
#  0.6805881099509908,
#  0.6784572767952269,
#  0.6723844023012998]

# %%
plt.plot(neighbors,metric_k,'o-')
plt.xlabel('k')
plt.ylabel('Accuracy')
plt.grid()

# %%
classifier = KNeighborsClassifier(n_neighbors= 5, metric = 'euclidean')
classifier.fit(x_train,y_train)
y_pred = classifier.predict(x_test)
acc = accuracy_score(y_test,y_pred)
metric_k.append(acc)

# %%
print('Accuracy = ',accuracy_score(y_test,y_pred))
print('Precision = ',precision_score(y_test,y_pred,average='micro'))
print('Recall = ',recall_score(y_test,y_pred,average='micro'))
print('F1 Score = ',f1_score(y_test,y_pred,average='micro'))
# Out:
# Accuracy =  0.782228851480929
# Precision =  0.782228851480929
# Recall =  0.782228851480929
# F1 Score =  0.782228851480929

# %% [markdown]
# **Decision Tree**- 73%

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt_cls = DecisionTreeClassifier()
model = dt_cls.fit(x_train,y_train)
y_pred_dt = model.predict(x_test)

# %%
confusion_matrix(y_test,y_pred_dt)
# Out:
# array([[1188,   40,  484],
#        [  31, 2004,  707],
#        [ 426,  677, 3829]])

# %%
accuracy_score(y_test,y_pred_dt)
# Out:
# 0.7480289793309184

# %% [markdown]
# **Random Forest**- 81%

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_cls = RandomForestClassifier(n_estimators= 12)
model_rf = rf_cls.fit(x_train,y_train)
y_pred_rf = model_rf.predict(x_test)

# %%
confusion_matrix(y_test,y_pred_rf)
# Out:
# array([[1317,    3,  392],
#        [   8, 2325,  409],
#        [ 302,  644, 3986]])

# %%
accuracy_score(y_test,y_pred_rf)
# Out:
# 0.8126997656083529

# %% [markdown]
# K-fold cross-validation to assess the performance of the machine learning model.

# %%
from sklearn.model_selection import KFold
k = KFold(10)
# 10 folds are taken

# %%
#split x and y
for train_index,test_index in k.split(x,Y):
  print('Training Index',train_index)
  print('Test Index',test_index)
# Out:
# Training Index [ 3755  3756  3757 ... 37539 37540 37541]
# Test Index [   0    1    2 ... 3752 3753 3754]
# Training Index [    0     1     2 ... 37539 37540 37541]
# Test Index [3755 3756 3757 ... 7507 7508 7509]
# Training Index [    0     1     2 ... 37539 37540 37541]
# Test Index [ 7510  7511  7512 ... 11261 11262 11263]
# Training Index [    0     1     2 ... 37539 37540 37541]
# Test Index [11264 11265 11266 ... 15015 15016 15017]
# Training Index [    0     1     2 ... 37539 37540 37541]
# Test Index [15018 15019 15020 ... 18769 18770 18771]
# Training Index [    0     1     2 ... 37539 37540 37541]
# Test Index [18772 18773 18774 ... 22523 22524 22525]
# Training Index [    0     1     2 ... 37539 37540 37541]
# Test Index [22526 22527 22528 ... 26277 26278 26279]
# Training Index [    0     1     2 ... 37539 37540 37541]
# Test Index [26280 26281 26282 ... 30031 30032 30033]
# Training Index [    0     1     2 ... 37539 37540 37541]
# ...

# %%
lrmodel=LogisticRegression()
lrmodel =lrmodel.fit(x_train,y_train)

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
#  Used for cross-validation evaluation of machine learning models.

# %%
cv_result = cross_val_score(lrmodel,x,Y,cv=k)

# %%
# Got 10 different scores
cv_result
# Out:
# array([1.        , 1.        , 1.        , 1.        , 1.        ,
#        1.        , 1.        , 1.        , 1.        , 0.99973362])

# %%
# calculation of the mean of a set of cross-validation results
np.mean(cv_result)
# Out:
# 0.9999733617474694

# %% [markdown]
#  Performing hyperparameter tuning

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
# Initializing the XGBoost classifier
xgb_model = XGBClassifier()

# %%
# Defining hyperparameters for fine-tuning using GridSearchCV
params = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.1, 0.01, 0.001],
    'n_estimators': [100, 200, 300]}

# %%
# Perform GridSearchCV for hyperparameter tuning
grid_search = GridSearchCV(estimator=xgb_model, param_grid=params, cv=3, scoring='accuracy')
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
# ...

# %%
# Get the best parameters
best_params = grid_search.best_params_

# %%
# Train the model with the best hyperparameters
final_model = XGBClassifier(**best_params)
final_model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
# Make predictions
predictions = final_model.predict(x_test)

# %%
# Evaluating the model
accuracy = accuracy_score(y_test, predictions)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.7948

# %%
import pickle

# %%
pickle.dump(model,open('model.pkl','wb'))

# %%
pickled_model = pickle.load(open('model.pkl', 'rb'))
